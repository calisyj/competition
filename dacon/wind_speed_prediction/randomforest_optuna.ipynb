# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
import optuna
 

# train.csv 파일 불러오기
train_data = pd.read_csv('train.csv')

# 결측치를 평균값으로 대체
train_data = train_data.fillna(train_data.mean())

# '측정 시간대'를 원핫 인코딩하여 숫자 형태로 변환
encoder = OneHotEncoder(sparse=False)
time_encoded = encoder.fit_transform(train_data[['측정 시간대']])
time_encoded_df = pd.DataFrame(time_encoded, columns=encoder.get_feature_names(['측정 시간대']))
train_data = pd.concat([train_data, time_encoded_df], axis=1).drop(['측정 시간대'], axis=1)

# 풍속을 예측할 특성(입력 변수)과 풍속(출력 변수)을 분리합니다.
X_train = train_data.drop(['ID', '풍속 (m/s)'], axis=1)  # 입력 변수들
y_train = train_data['풍속 (m/s)']  # 출력 변수 (풍속)

# Optuna Objective 함수 정의
def objective(trial):
    # RandomForestRegressor의 파라미터 범위 설정
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 5, 15)
    min_samples_split = trial.suggest_float('min_samples_split', 0.1, 1.0)
    min_samples_leaf = trial.suggest_float('min_samples_leaf', 0.1, 0.5)

    # RandomForestRegressor 모델 생성
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42
    )

    # 모델 학습
    model.fit(X_train, y_train)

    # 검증 데이터에 대한 예측 결과
    y_pred = model.predict(X_train)

    # 평균제곱오차를 최소화하는 것이 목표
    mse = mean_squared_error(y_train, y_pred)

    return mse

# Optuna로 파라미터 최적화
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

# 최적 파라미터 출력
print("최적 파라미터: ", study.best_params)
print("최적 Objective 값: ", study.best_value)

# 최적 파라미터로 모델 재학습
best_params = study.best_params
best_model = RandomForestRegressor(**best_params, random_state=42)
best_model.fit(X_train, y_train)

# test.csv 파일 불러오기
test_data = pd.read_csv('test.csv')

# 결측치를 평균값으로 대체
test_data = test_data.fillna(test_data.mean())

# '측정 시간대'를 원핫 인코딩하여 숫자 형태로 변환
time_encoded = encoder.transform(test_data[['측정 시간대']])
time_encoded_df = pd.DataFrame(time_encoded, columns=encoder.get_feature_names(['측정 시간대']))
test_data = pd.concat([test_data, time_encoded_df], axis=1).drop(['측정 시간대'], axis=1)

# 테스트 데이터로 풍속 예측을 수행합니다.
X_test = test_data.drop('ID', axis=1)  # 테스트 입력 변수들
y_pred = best_model.predict(X_test)  # 테스트 데이터로 풍속 예측

# Submit / 제출
submission = pd.read_csv('./sample_submission.csv')
submission['풍속 (m/s)'] = y_pred

# 예측 결과를 submission.csv 양식에 맞게 저장합니다.
submission.to_csv('submission.csv', index=False)

print("풍속 예측이 완료되었습니다. 결과가 submission.csv에 저장되었습니다.")
# Out:
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# [I 2023-07-25 00:31:30,886] A new study created in memory with name: no-name-27907b95-bca8-4bb0-b2e7-27791a8a83ab
# [I 2023-07-25 00:31:31,238] Trial 0 finished with value: 2.3843233819693546 and parameters: {'n_estimators': 106, 'max_depth': 6, 'min_samples_split': 0.2979986454882762, 'min_samples_leaf': 0.43296234010544354}. Best is trial 0 with value: 2.3843233819693546.
# [I 2023-07-25 00:31:31,471] Trial 1 finished with value: 2.3843242282888055 and parameters: {'n_estimators': 73, 'max_depth': 7, 'min_samples_split': 0.7956375153307056, 'min_samples_leaf': 0.19785947526505887}. Best is trial 0 with value: 2.3843233819693546.
# [I 2023-07-25 00:31:31,843] Trial 2 finished with value: 2.3843230937261763 and parameters: {'n_estimators': 125, 'max_depth': 12, 'min_samples_split': 0.8813964376145657, 'min_samples_leaf': 0.446114239739243}. Best is trial 2 with value: 2.3843230937261763.
# [I 2023-07-25 00:31:32,007] Trial 3 finished with value: 2.384323158911034 and parameters: {'n_estimators': 63, 'max_depth': 11, 'min_samples_split': 0.7962006094964106, 'min_samples_leaf': 0.18941901468822353}. Best is trial 2 with value: 2.3843230937261763.
# [I 2023-07-25 00:31:32,440] Trial 4 finished with value: 2.3843233353728084 and parameters: {'n_estimators': 133, 'max_depth': 9, 'min_samples_split': 0.3331922984041489, 'min_samples_leaf': 0.44589426838279966}. Best is trial 2 with value: 2.3843230937261763.
# [I 2023-07-25 00:31:32,787] Trial 5 finished with value: 2.384323322234966 and parameters: {'n_estimators': 112, 'max_depth': 9, 'min_samples_split': 0.7112346477862423, 'min_samples_leaf': 0.22428906243273228}. Best is trial 2 with value: 2.3843230937261763.
# [I 2023-07-25 00:31:33,081] Trial 6 finished with value: 2.3843247201267306 and parameters: {'n_estimators': 89, 'max_depth': 8, 'min_samples_split': 0.9685033135592109, 'min_samples_leaf': 0.2830127306921707}. Best is trial 2 with value: 2.3843230937261763.
# [I 2023-07-25 00:31:33,693] Trial 7 finished with value: 2.38432273903164 and parameters: {'n_estimators': 189, 'max_depth': 11, 'min_samples_split': 0.6601965979654167, 'min_samples_leaf': 0.3278006985988576}. Best is trial 7 with value: 2.38432273903164.
# [I 2023-07-25 00:31:34,189] Trial 8 finished with value: 2.384323024179672 and parameters: {'n_estimators': 167, 'max_depth': 14, 'min_samples_split': 0.7410328202254167, 'min_samples_leaf': 0.20536056974454692}. Best is trial 7 with value: 2.38432273903164.
# [I 2023-07-25 00:31:34,623] Trial 9 finished with value: 2.38432322477796 and parameters: {'n_estimators': 145, 'max_depth': 5, 'min_samples_split': 0.8760611239908792, 'min_samples_leaf': 0.38605348877292256}. Best is trial 7 with value: 2.38432273903164.
# [I 2023-07-25 00:31:40,874] Trial 10 finished with value: 2.160618712337966 and parameters: {'n_estimators': 198, 'max_depth': 15, 'min_samples_split': 0.5203390367697319, 'min_samples_leaf': 0.10650556570340183}. Best is trial 10 with value: 2.160618712337966.
# [I 2023-07-25 00:31:47,095] Trial 11 finished with value: 2.160567436896659 and parameters: {'n_estimators': 196, 'max_depth': 15, 'min_samples_split': 0.5529906579256461, 'min_samples_leaf': 0.11585356865392038}. Best is trial 11 with value: 2.160567436896659.
# [I 2023-07-25 00:31:53,943] Trial 12 finished with value: 2.160592713451227 and parameters: {'n_estimators': 197, 'max_depth': 15, 'min_samples_split': 0.4970629933460584, 'min_samples_leaf': 0.12513663715934212}. Best is trial 11 with value: 2.160567436896659.
# [I 2023-07-25 00:31:59,466] Trial 13 finished with value: 2.160630721180799 and parameters: {'n_estimators': 168, 'max_depth': 13, 'min_samples_split': 0.5250034469875967, 'min_samples_leaf': 0.10448370929648924}. Best is trial 11 with value: 2.160567436896659.
# [I 2023-07-25 00:32:04,502] Trial 14 finished with value: 2.160470823937868 and parameters: {'n_estimators': 175, 'max_depth': 15, 'min_samples_split': 0.44224474566588046, 'min_samples_leaf': 0.1433594735568328}. Best is trial 14 with value: 2.160470823937868.
# [I 2023-07-25 00:32:12,126] Trial 15 finished with value: 2.092396227825954 and parameters: {'n_estimators': 167, 'max_depth': 13, 'min_samples_split': 0.1621900010513499, 'min_samples_leaf': 0.14439947538804235}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:32:18,800] Trial 16 finished with value: 2.1396646331955695 and parameters: {'n_estimators': 164, 'max_depth': 13, 'min_samples_split': 0.10599867270462715, 'min_samples_leaf': 0.1612437358294784}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:32:25,250] Trial 17 finished with value: 2.125987242359359 and parameters: {'n_estimators': 155, 'max_depth': 13, 'min_samples_split': 0.12085799467070929, 'min_samples_leaf': 0.15698048703409365}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:32:29,506] Trial 18 finished with value: 2.160732733388557 and parameters: {'n_estimators': 147, 'max_depth': 13, 'min_samples_split': 0.11169525823208351, 'min_samples_leaf': 0.24866287990582825}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:32:35,426] Trial 19 finished with value: 2.142630975497954 and parameters: {'n_estimators': 150, 'max_depth': 11, 'min_samples_split': 0.18331185131395827, 'min_samples_leaf': 0.16857501671749797}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:32:40,402] Trial 20 finished with value: 2.160529021475819 and parameters: {'n_estimators': 179, 'max_depth': 12, 'min_samples_split': 0.23368340827399275, 'min_samples_leaf': 0.24657192916333986}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:32:46,688] Trial 21 finished with value: 2.142374548555035 and parameters: {'n_estimators': 159, 'max_depth': 13, 'min_samples_split': 0.10036355605011436, 'min_samples_leaf': 0.16477770323992885}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:32:52,706] Trial 22 finished with value: 2.125690588263989 and parameters: {'n_estimators': 138, 'max_depth': 12, 'min_samples_split': 0.17928405584891807, 'min_samples_leaf': 0.14985979066227653}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:32:58,681] Trial 23 finished with value: 2.126521311640707 and parameters: {'n_estimators': 135, 'max_depth': 12, 'min_samples_split': 0.21478407658448057, 'min_samples_leaf': 0.15130488436294348}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:33:03,758] Trial 24 finished with value: 2.127016025856849 and parameters: {'n_estimators': 112, 'max_depth': 10, 'min_samples_split': 0.31840545345687166, 'min_samples_leaf': 0.13624055105271726}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:33:08,783] Trial 25 finished with value: 2.1596878009099156 and parameters: {'n_estimators': 153, 'max_depth': 14, 'min_samples_split': 0.1776436738574915, 'min_samples_leaf': 0.18301881067479056}. Best is trial 15 with value: 2.092396227825954.
# [I 2023-07-25 00:33:18,365] Trial 26 finished with value: 2.065920861390966 and parameters: {'n_estimators': 182, 'max_depth': 14, 'min_samples_split': 0.2638099990180507, 'min_samples_leaf': 0.13896099834292538}. Best is trial 26 with value: 2.065920861390966.
# [I 2023-07-25 00:33:27,848] Trial 27 finished with value: 2.0458750597536093 and parameters: {'n_estimators': 179, 'max_depth': 14, 'min_samples_split': 0.2652410057912953, 'min_samples_leaf': 0.12740841203179334}. Best is trial 27 with value: 2.0458750597536093.
# [I 2023-07-25 00:33:33,463] Trial 28 finished with value: 2.1605843061699237 and parameters: {'n_estimators': 184, 'max_depth': 14, 'min_samples_split': 0.40603852665952606, 'min_samples_leaf': 0.10463734100287952}. Best is trial 27 with value: 2.0458750597536093.
# [I 2023-07-25 00:33:38,215] Trial 29 finished with value: 2.1604687938901885 and parameters: {'n_estimators': 177, 'max_depth': 14, 'min_samples_split': 0.26264293548417394, 'min_samples_leaf': 0.2156231940792694}. Best is trial 27 with value: 2.0458750597536093.
# [I 2023-07-25 00:33:47,909] Trial 30 finished with value: 2.092690898056708 and parameters: {'n_estimators': 189, 'max_depth': 14, 'min_samples_split': 0.2899643024423757, 'min_samples_leaf': 0.12906362411917074}. Best is trial 27 with value: 2.0458750597536093.
# [I 2023-07-25 00:33:58,214] Trial 31 finished with value: 2.056423945678192 and parameters: {'n_estimators': 187, 'max_depth': 14, 'min_samples_split': 0.2789184666250899, 'min_samples_leaf': 0.12795792578750526}. Best is trial 27 with value: 2.0458750597536093.
# [I 2023-07-25 00:34:04,209] Trial 32 finished with value: 2.1553713105249472 and parameters: {'n_estimators': 176, 'max_depth': 15, 'min_samples_split': 0.34073182935523844, 'min_samples_leaf': 0.17803595917795945}. Best is trial 27 with value: 2.0458750597536093.
# [I 2023-07-25 00:34:16,331] Trial 33 finished with value: 2.051548474808704 and parameters: {'n_estimators': 188, 'max_depth': 14, 'min_samples_split': 0.2643031781693322, 'min_samples_leaf': 0.1296926102326727}. Best is trial 27 with value: 2.0458750597536093.
# [I 2023-07-25 00:34:27,648] Trial 34 finished with value: 2.0405435790852917 and parameters: {'n_estimators': 186, 'max_depth': 14, 'min_samples_split': 0.2581846724276928, 'min_samples_leaf': 0.12659478815695174}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:34:37,228] Trial 35 finished with value: 2.128140550088015 and parameters: {'n_estimators': 189, 'max_depth': 6, 'min_samples_split': 0.33315527533468675, 'min_samples_leaf': 0.10064349649307434}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:34:39,868] Trial 36 finished with value: 2.161224701901818 and parameters: {'n_estimators': 54, 'max_depth': 12, 'min_samples_split': 0.23035881395493557, 'min_samples_leaf': 0.19345025070818478}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:34:44,003] Trial 37 finished with value: 2.1610970073366955 and parameters: {'n_estimators': 89, 'max_depth': 11, 'min_samples_split': 0.38009882572821985, 'min_samples_leaf': 0.12071731289260736}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:34:51,731] Trial 38 finished with value: 2.160336592367513 and parameters: {'n_estimators': 191, 'max_depth': 14, 'min_samples_split': 0.2910721386015691, 'min_samples_leaf': 0.18562351125406754}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:34:57,017] Trial 39 finished with value: 2.1567436298957556 and parameters: {'n_estimators': 123, 'max_depth': 10, 'min_samples_split': 0.3572179773826885, 'min_samples_leaf': 0.12829036908371896}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:35:03,876] Trial 40 finished with value: 2.1604655726896187 and parameters: {'n_estimators': 173, 'max_depth': 8, 'min_samples_split': 0.28474663725103694, 'min_samples_leaf': 0.20054419952515062}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:35:14,955] Trial 41 finished with value: 2.055288976164757 and parameters: {'n_estimators': 183, 'max_depth': 14, 'min_samples_split': 0.24856096714643336, 'min_samples_leaf': 0.1358362161586378}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:35:23,494] Trial 42 finished with value: 2.1452312251514907 and parameters: {'n_estimators': 200, 'max_depth': 15, 'min_samples_split': 0.23979048070041564, 'min_samples_leaf': 0.17154058325241425}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:35:34,229] Trial 43 finished with value: 2.1103267648204214 and parameters: {'n_estimators': 185, 'max_depth': 14, 'min_samples_split': 0.31276375913665116, 'min_samples_leaf': 0.1210149040135563}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:35:42,866] Trial 44 finished with value: 2.160490401709421 and parameters: {'n_estimators': 193, 'max_depth': 15, 'min_samples_split': 0.38496942948823676, 'min_samples_leaf': 0.13698195384916506}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:35:52,030] Trial 45 finished with value: 2.1364375241802365 and parameters: {'n_estimators': 170, 'max_depth': 13, 'min_samples_split': 0.20748627511108908, 'min_samples_leaf': 0.16027811183532967}. Best is trial 34 with value: 2.0405435790852917.
# [I 2023-07-25 00:36:03,332] Trial 46 finished with value: 2.0277935268544938 and parameters: {'n_estimators': 160, 'max_depth': 14, 'min_samples_split': 0.26347941829523197, 'min_samples_leaf': 0.10017543568457372}. Best is trial 46 with value: 2.0277935268544938.
# [I 2023-07-25 00:36:15,200] Trial 47 finished with value: 2.0201170851085286 and parameters: {'n_estimators': 158, 'max_depth': 15, 'min_samples_split': 0.1578459954924345, 'min_samples_leaf': 0.11461973649582453}. Best is trial 47 with value: 2.0201170851085286.
# [I 2023-07-25 00:36:28,978] Trial 48 finished with value: 2.0216138294839308 and parameters: {'n_estimators': 162, 'max_depth': 15, 'min_samples_split': 0.20057758900929967, 'min_samples_leaf': 0.11331044900857924}. Best is trial 47 with value: 2.0201170851085286.
# [I 2023-07-25 00:36:47,440] Trial 49 finished with value: 2.0136528588624802 and parameters: {'n_estimators': 160, 'max_depth': 15, 'min_samples_split': 0.15018842909775312, 'min_samples_leaf': 0.10882996688807327}. Best is trial 49 with value: 2.0136528588624802.
# [I 2023-07-25 00:37:04,852] Trial 50 finished with value: 2.008215072360849 and parameters: {'n_estimators': 163, 'max_depth': 15, 'min_samples_split': 0.14910548534957116, 'min_samples_leaf': 0.10478668870775536}. Best is trial 50 with value: 2.008215072360849.
# [I 2023-07-25 00:37:21,995] Trial 51 finished with value: 2.007948991939429 and parameters: {'n_estimators': 159, 'max_depth': 15, 'min_samples_split': 0.1515115334148046, 'min_samples_leaf': 0.1046840527595441}. Best is trial 51 with value: 2.007948991939429.
# [I 2023-07-25 00:37:39,971] Trial 52 finished with value: 2.006165397068085 and parameters: {'n_estimators': 162, 'max_depth': 15, 'min_samples_split': 0.1405001183325782, 'min_samples_leaf': 0.10298748949911718}. Best is trial 52 with value: 2.006165397068085.
# [I 2023-07-25 00:37:54,167] Trial 53 finished with value: 2.02019799313077 and parameters: {'n_estimators': 145, 'max_depth': 15, 'min_samples_split': 0.13852540337984154, 'min_samples_leaf': 0.1161290731715955}. Best is trial 52 with value: 2.006165397068085.
# [I 2023-07-25 00:38:08,480] Trial 54 finished with value: 2.0178342401550515 and parameters: {'n_estimators': 140, 'max_depth': 15, 'min_samples_split': 0.14741594373252453, 'min_samples_leaf': 0.11121575414854651}. Best is trial 52 with value: 2.006165397068085.
# [I 2023-07-25 00:38:22,095] Trial 55 finished with value: 2.0105381586530227 and parameters: {'n_estimators': 128, 'max_depth': 15, 'min_samples_split': 0.1631066780528543, 'min_samples_leaf': 0.10049920757198695}. Best is trial 52 with value: 2.006165397068085.
# [I 2023-07-25 00:38:35,058] Trial 56 finished with value: 2.0060612960180637 and parameters: {'n_estimators': 126, 'max_depth': 15, 'min_samples_split': 0.13984750662652912, 'min_samples_leaf': 0.10164501005211}. Best is trial 56 with value: 2.0060612960180637.
# [I 2023-07-25 00:38:47,838] Trial 57 finished with value: 2.0081521941749307 and parameters: {'n_estimators': 121, 'max_depth': 15, 'min_samples_split': 0.12859314931068852, 'min_samples_leaf': 0.10112983904615688}. Best is trial 56 with value: 2.0060612960180637.
# [I 2023-07-25 00:38:57,328] Trial 58 finished with value: 2.1266295845279712 and parameters: {'n_estimators': 129, 'max_depth': 15, 'min_samples_split': 0.10159927359379368, 'min_samples_leaf': 0.14703297013179634}. Best is trial 56 with value: 2.0060612960180637.
# [I 2023-07-25 00:39:09,502] Trial 59 finished with value: 2.005962064891046 and parameters: {'n_estimators': 118, 'max_depth': 15, 'min_samples_split': 0.127097908260245, 'min_samples_leaf': 0.10190293030324359}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:39:14,944] Trial 60 finished with value: 2.1504818365385625 and parameters: {'n_estimators': 99, 'max_depth': 13, 'min_samples_split': 0.193589469032984, 'min_samples_leaf': 0.17330269308738766}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:39:27,483] Trial 61 finished with value: 2.0105767452005745 and parameters: {'n_estimators': 119, 'max_depth': 15, 'min_samples_split': 0.13609924810748883, 'min_samples_leaf': 0.10059678592707166}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:39:35,410] Trial 62 finished with value: 2.12704965823752 and parameters: {'n_estimators': 112, 'max_depth': 15, 'min_samples_split': 0.12857461295588252, 'min_samples_leaf': 0.15088996521796016}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:39:42,707] Trial 63 finished with value: 2.1252869886957826 and parameters: {'n_estimators': 103, 'max_depth': 15, 'min_samples_split': 0.17189455277459117, 'min_samples_leaf': 0.14769505169935243}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:39:54,402] Trial 64 finished with value: 2.0194606823445467 and parameters: {'n_estimators': 130, 'max_depth': 15, 'min_samples_split': 0.21169338959664255, 'min_samples_leaf': 0.1156984665167634}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:40:02,748] Trial 65 finished with value: 2.1300794411895705 and parameters: {'n_estimators': 120, 'max_depth': 15, 'min_samples_split': 0.1004252802638683, 'min_samples_leaf': 0.1582252549759566}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:40:12,717] Trial 66 finished with value: 2.0079082789274936 and parameters: {'n_estimators': 94, 'max_depth': 13, 'min_samples_split': 0.1811692800446923, 'min_samples_leaf': 0.10146344652086126}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:40:20,579] Trial 67 finished with value: 2.060265670978424 and parameters: {'n_estimators': 90, 'max_depth': 13, 'min_samples_split': 0.1329871025542832, 'min_samples_leaf': 0.13812435223488626}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:40:27,988] Trial 68 finished with value: 2.025488113820756 and parameters: {'n_estimators': 77, 'max_depth': 14, 'min_samples_split': 0.1884087754789512, 'min_samples_leaf': 0.11273345283500684}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:40:34,286] Trial 69 finished with value: 2.0705282699644876 and parameters: {'n_estimators': 76, 'max_depth': 9, 'min_samples_split': 0.12345166216786502, 'min_samples_leaf': 0.14160905912025606}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:40:43,160] Trial 70 finished with value: 2.019071357672508 and parameters: {'n_estimators': 98, 'max_depth': 13, 'min_samples_split': 0.22020678797972612, 'min_samples_leaf': 0.12056952273654425}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:40:54,487] Trial 71 finished with value: 2.008202335470702 and parameters: {'n_estimators': 108, 'max_depth': 15, 'min_samples_split': 0.17335100186219116, 'min_samples_leaf': 0.10105839936204172}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:41:05,208] Trial 72 finished with value: 2.013217949643281 and parameters: {'n_estimators': 108, 'max_depth': 15, 'min_samples_split': 0.17023549862531961, 'min_samples_leaf': 0.10859715793185429}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:41:12,428] Trial 73 finished with value: 2.0516952293716333 and parameters: {'n_estimators': 83, 'max_depth': 14, 'min_samples_split': 0.1950549416598995, 'min_samples_leaf': 0.12779982356914749}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:41:22,576] Trial 74 finished with value: 2.019620803017556 and parameters: {'n_estimators': 116, 'max_depth': 15, 'min_samples_split': 0.15685017686698427, 'min_samples_leaf': 0.11721141867091417}. Best is trial 59 with value: 2.005962064891046.
# [I 2023-07-25 00:41:37,993] Trial 75 finished with value: 2.005169103561086 and parameters: {'n_estimators': 151, 'max_depth': 14, 'min_samples_split': 0.11823339420011628, 'min_samples_leaf': 0.10228496209296194}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:41:53,136] Trial 76 finished with value: 2.007627910658548 and parameters: {'n_estimators': 143, 'max_depth': 14, 'min_samples_split': 0.11513591062404441, 'min_samples_leaf': 0.10068337872362018}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:42:06,378] Trial 77 finished with value: 2.0540191584176597 and parameters: {'n_estimators': 150, 'max_depth': 14, 'min_samples_split': 0.10076401012426742, 'min_samples_leaf': 0.1336290663709784}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:42:16,202] Trial 78 finished with value: 2.1291249914244914 and parameters: {'n_estimators': 143, 'max_depth': 13, 'min_samples_split': 0.13119926328371337, 'min_samples_leaf': 0.1585461356256884}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:42:28,310] Trial 79 finished with value: 2.0195905280055055 and parameters: {'n_estimators': 134, 'max_depth': 5, 'min_samples_split': 0.22601779676173683, 'min_samples_leaf': 0.12201797184383788}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:42:40,626] Trial 80 finished with value: 2.0806382157755823 and parameters: {'n_estimators': 154, 'max_depth': 14, 'min_samples_split': 0.1215749011731796, 'min_samples_leaf': 0.14369162924244155}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:42:53,814] Trial 81 finished with value: 2.0111121026219863 and parameters: {'n_estimators': 125, 'max_depth': 14, 'min_samples_split': 0.17889648977693512, 'min_samples_leaf': 0.10026631739557887}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:43:06,284] Trial 82 finished with value: 2.0194337994071696 and parameters: {'n_estimators': 138, 'max_depth': 14, 'min_samples_split': 0.11963832470054767, 'min_samples_leaf': 0.1218881265281331}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:43:17,014] Trial 83 finished with value: 2.0171586782595248 and parameters: {'n_estimators': 108, 'max_depth': 15, 'min_samples_split': 0.18018383841500507, 'min_samples_leaf': 0.11052279251168959}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:43:27,300] Trial 84 finished with value: 2.0556419083366397 and parameters: {'n_estimators': 114, 'max_depth': 14, 'min_samples_split': 0.15928786530673328, 'min_samples_leaf': 0.1333888545640488}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:43:36,318] Trial 85 finished with value: 2.0183598117371173 and parameters: {'n_estimators': 93, 'max_depth': 15, 'min_samples_split': 0.21246996050070924, 'min_samples_leaf': 0.11097138016054865}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:43:45,516] Trial 86 finished with value: 2.044496358909382 and parameters: {'n_estimators': 102, 'max_depth': 14, 'min_samples_split': 0.23460107655533044, 'min_samples_leaf': 0.1273391494346997}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:44:00,394] Trial 87 finished with value: 2.012107190097854 and parameters: {'n_estimators': 151, 'max_depth': 15, 'min_samples_split': 0.11427106996975334, 'min_samples_leaf': 0.10839161000983485}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:44:15,205] Trial 88 finished with value: 2.0207940965427142 and parameters: {'n_estimators': 167, 'max_depth': 6, 'min_samples_split': 0.14031825588032726, 'min_samples_leaf': 0.11974486670663578}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:44:27,879] Trial 89 finished with value: 2.0081545387049573 and parameters: {'n_estimators': 122, 'max_depth': 15, 'min_samples_split': 0.20370599448791316, 'min_samples_leaf': 0.10087267304596899}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:44:32,427] Trial 90 finished with value: 2.143356749232311 and parameters: {'n_estimators': 68, 'max_depth': 14, 'min_samples_split': 0.20142674013534417, 'min_samples_leaf': 0.1664112828151457}. Best is trial 75 with value: 2.005169103561086.
# [I 2023-07-25 00:44:44,965] Trial 91 finished with value: 2.004508047512158 and parameters: {'n_estimators': 121, 'max_depth': 15, 'min_samples_split': 0.16896050258998352, 'min_samples_leaf': 0.10244725326986642}. Best is trial 91 with value: 2.004508047512158.
# [I 2023-07-25 00:44:55,774] Trial 92 finished with value: 2.0559592515083853 and parameters: {'n_estimators': 121, 'max_depth': 15, 'min_samples_split': 0.15025973406774623, 'min_samples_leaf': 0.13472346028121934}. Best is trial 91 with value: 2.004508047512158.
# [I 2023-07-25 00:45:09,486] Trial 93 finished with value: 2.010840222388253 and parameters: {'n_estimators': 142, 'max_depth': 15, 'min_samples_split': 0.1153545991085938, 'min_samples_leaf': 0.10793281716453494}. Best is trial 91 with value: 2.004508047512158.
# [I 2023-07-25 00:45:20,894] Trial 94 finished with value: 2.0193488181678476 and parameters: {'n_estimators': 132, 'max_depth': 15, 'min_samples_split': 0.24347682095244552, 'min_samples_leaf': 0.12078067756591651}. Best is trial 91 with value: 2.004508047512158.
# [I 2023-07-25 00:45:36,746] Trial 95 finished with value: 2.0088733196593935 and parameters: {'n_estimators': 147, 'max_depth': 14, 'min_samples_split': 0.1633319288782141, 'min_samples_leaf': 0.1003395606683985}. Best is trial 91 with value: 2.004508047512158.
# [I 2023-07-25 00:45:48,067] Trial 96 finished with value: 2.0511363365281565 and parameters: {'n_estimators': 126, 'max_depth': 13, 'min_samples_split': 0.19462305921335324, 'min_samples_leaf': 0.12839710842884972}. Best is trial 91 with value: 2.004508047512158.
# [I 2023-07-25 00:45:56,572] Trial 97 finished with value: 2.1265806785755283 and parameters: {'n_estimators': 117, 'max_depth': 7, 'min_samples_split': 0.14258675669093118, 'min_samples_leaf': 0.15135019088353835}. Best is trial 91 with value: 2.004508047512158.
# [I 2023-07-25 00:46:09,122] Trial 98 finished with value: 2.0199295565064563 and parameters: {'n_estimators': 136, 'max_depth': 11, 'min_samples_split': 0.12172225795900043, 'min_samples_leaf': 0.1115458711585494}. Best is trial 91 with value: 2.004508047512158.
# [I 2023-07-25 00:46:21,557] Trial 99 finished with value: 2.0804834580523037 and parameters: {'n_estimators': 155, 'max_depth': 15, 'min_samples_split': 0.18261721073193513, 'min_samples_leaf': 0.14343569041108578}. Best is trial 91 with value: 2.004508047512158.
# 최적 파라미터:  {'n_estimators': 121, 'max_depth': 15, 'min_samples_split': 0.16896050258998352, 'min_samples_leaf': 0.10244725326986642}
# 최적 Objective 값:  2.004508047512158
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:68: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 풍속 예측이 완료되었습니다. 결과가 submission.csv에 저장되었습니다.

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
# Cross Validation을 활용하여 평균 RMSE 계산
scores = cross_val_score(best_model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
rmse_scores = np.sqrt(-scores)

print("평균 RMSE:", np.mean(rmse_scores))
# Out:
# 평균 RMSE: 1.4170601386529476
