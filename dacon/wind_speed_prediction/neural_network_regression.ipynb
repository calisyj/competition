# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# train.csv 파일 불러오기
train_data = pd.read_csv('train.csv')

# 결측치를 평균값으로 대체
train_data = train_data.fillna(train_data.mean())

# '측정 시간대'를 원핫 인코딩하여 숫자 형태로 변환
encoder = OneHotEncoder(sparse=False)
time_encoded = encoder.fit_transform(train_data[['측정 시간대']])
time_encoded_df = pd.DataFrame(time_encoded, columns=encoder.get_feature_names(['측정 시간대']))
train_data = pd.concat([train_data, time_encoded_df], axis=1).drop(['측정 시간대'], axis=1)

# 풍속을 예측할 특성(입력 변수)과 풍속(출력 변수)을 분리합니다.
X_train = train_data.drop(['ID', '풍속 (m/s)'], axis=1)  # 입력 변수들
y_train = train_data['풍속 (m/s)']  # 출력 변수 (풍속)

# 신경망 모델 구성
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])

# 모델 컴파일
model.compile(optimizer='adam', loss='mean_squared_error')

# 데이터 정규화 (Normalization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# 신경망 모델 학습
model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2)

# test.csv 파일 불러오기
test_data = pd.read_csv('test.csv')

# 결측치를 평균값으로 대체
test_data = test_data.fillna(test_data.mean())

# '측정 시간대'를 원핫 인코딩하여 숫자 형태로 변환
time_encoded = encoder.transform(test_data[['측정 시간대']])
time_encoded_df = pd.DataFrame(time_encoded, columns=encoder.get_feature_names(['측정 시간대']))
test_data = pd.concat([test_data, time_encoded_df], axis=1).drop(['측정 시간대'], axis=1)

# 테스트 데이터 정규화 (Normalization)
X_test_scaled = scaler.transform(test_data.drop('ID', axis=1))

# 테스트 데이터로 풍속 예측을 수행합니다.
y_pred = model.predict(X_test_scaled).flatten()  # 테스트 데이터로 풍속 예측

# Submit / 제출
submission = pd.read_csv('./sample_submission.csv')
submission['풍속 (m/s)'] = y_pred

# 예측 결과를 submission.csv 양식에 맞게 저장합니다.
submission.to_csv('submission.csv', index=False)

print("풍속 예측이 완료되었습니다. 결과가 submission.csv에 저장되었습니다.")
# Out:
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Epoch 1/100
# 915/915 [==============================] - 2s 2ms/step - loss: 1.5991 - val_loss: 1.4238
# Epoch 2/100
# 915/915 [==============================] - 1s 1ms/step - loss: 1.2428 - val_loss: 1.1946
# Epoch 3/100
# 915/915 [==============================] - 2s 2ms/step - loss: 1.1223 - val_loss: 1.0958
# Epoch 4/100
# 915/915 [==============================] - 3s 3ms/step - loss: 1.0454 - val_loss: 1.0480
# Epoch 5/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.9825 - val_loss: 1.0972
# Epoch 6/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.9332 - val_loss: 0.9785
# Epoch 7/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.8938 - val_loss: 0.9906
# Epoch 8/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.8624 - val_loss: 0.8875
# Epoch 9/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.8424 - val_loss: 0.8888
# Epoch 10/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.8180 - val_loss: 0.8888
# Epoch 11/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.7958 - val_loss: 0.8252
# Epoch 12/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.7755 - val_loss: 0.8162
# Epoch 13/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.7593 - val_loss: 0.8072
# Epoch 14/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.7529 - val_loss: 0.8156
# Epoch 15/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.7307 - val_loss: 0.7876
# Epoch 16/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.7219 - val_loss: 0.7850
# Epoch 17/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.7129 - val_loss: 0.8011
# Epoch 18/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.7029 - val_loss: 0.7508
# Epoch 19/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6967 - val_loss: 0.7420
# Epoch 20/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.6858 - val_loss: 0.7549
# Epoch 21/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6775 - val_loss: 0.7368
# Epoch 22/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6724 - val_loss: 0.7149
# Epoch 23/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.6624 - val_loss: 0.7445
# Epoch 24/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.6558 - val_loss: 0.7371
# Epoch 25/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6491 - val_loss: 0.7054
# Epoch 26/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.6417 - val_loss: 0.7113
# Epoch 27/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.6328 - val_loss: 0.7427
# Epoch 28/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.6287 - val_loss: 0.6790
# Epoch 29/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6250 - val_loss: 0.6951
# Epoch 30/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6268 - val_loss: 0.6993
# Epoch 31/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.6169 - val_loss: 0.6886
# Epoch 32/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6077 - val_loss: 0.6767
# Epoch 33/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6112 - val_loss: 0.7168
# Epoch 34/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6071 - val_loss: 0.6588
# Epoch 35/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5955 - val_loss: 0.6716
# Epoch 36/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5947 - val_loss: 0.6671
# Epoch 37/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.6001 - val_loss: 0.6759
# Epoch 38/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5889 - val_loss: 0.6588
# Epoch 39/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5816 - val_loss: 0.6639
# Epoch 40/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5790 - val_loss: 0.6512
# Epoch 41/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5771 - val_loss: 0.6463
# Epoch 42/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5707 - val_loss: 0.7056
# Epoch 43/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5699 - val_loss: 0.6374
# Epoch 44/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5626 - val_loss: 0.6544
# Epoch 45/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5649 - val_loss: 0.7151
# Epoch 46/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5608 - val_loss: 0.6370
# Epoch 47/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5572 - val_loss: 0.6308
# Epoch 48/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5588 - val_loss: 0.6549
# Epoch 49/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5546 - val_loss: 0.6492
# Epoch 50/100
# 915/915 [==============================] - 3s 4ms/step - loss: 0.5463 - val_loss: 0.6309
# Epoch 51/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5519 - val_loss: 0.6344
# Epoch 52/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.5420 - val_loss: 0.6539
# Epoch 53/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5398 - val_loss: 0.6111
# Epoch 54/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5414 - val_loss: 0.6107
# Epoch 55/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5385 - val_loss: 0.6180
# Epoch 56/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5352 - val_loss: 0.6038
# Epoch 57/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5395 - val_loss: 0.6538
# Epoch 58/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5277 - val_loss: 0.6173
# Epoch 59/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.5235 - val_loss: 0.6446
# Epoch 60/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.5285 - val_loss: 0.6127
# Epoch 61/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5231 - val_loss: 0.6521
# Epoch 62/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5198 - val_loss: 0.5886
# Epoch 63/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5246 - val_loss: 0.6028
# Epoch 64/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5219 - val_loss: 0.6133
# Epoch 65/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5125 - val_loss: 0.5976
# Epoch 66/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5137 - val_loss: 0.6002
# Epoch 67/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5113 - val_loss: 0.5998
# Epoch 68/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5135 - val_loss: 0.6243
# Epoch 69/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5077 - val_loss: 0.5732
# Epoch 70/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5073 - val_loss: 0.6105
# Epoch 71/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5063 - val_loss: 0.6169
# Epoch 72/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5017 - val_loss: 0.5990
# Epoch 73/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5044 - val_loss: 0.5959
# Epoch 74/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5010 - val_loss: 0.5863
# Epoch 75/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.5062 - val_loss: 0.5716
# Epoch 76/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.4981 - val_loss: 0.6310
# Epoch 77/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.4968 - val_loss: 0.6069
# Epoch 78/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4943 - val_loss: 0.6023
# Epoch 79/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4941 - val_loss: 0.5734
# Epoch 80/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4905 - val_loss: 0.5681
# Epoch 81/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4939 - val_loss: 0.5707
# Epoch 82/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.4889 - val_loss: 0.6160
# Epoch 83/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.4860 - val_loss: 0.5879
# Epoch 84/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.4850 - val_loss: 0.5708
# Epoch 85/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4879 - val_loss: 0.5755
# Epoch 86/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4822 - val_loss: 0.5831
# Epoch 87/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.4819 - val_loss: 0.5922
# Epoch 88/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.4826 - val_loss: 0.5556
# Epoch 89/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4785 - val_loss: 0.5688
# Epoch 90/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4788 - val_loss: 0.5803
# Epoch 91/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4774 - val_loss: 0.5662
# Epoch 92/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4742 - val_loss: 0.5638
# Epoch 93/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4732 - val_loss: 0.5967
# Epoch 94/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4701 - val_loss: 0.5671
# Epoch 95/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.4697 - val_loss: 0.5687
# Epoch 96/100
# 915/915 [==============================] - 2s 3ms/step - loss: 0.4673 - val_loss: 0.5797
# Epoch 97/100
# 915/915 [==============================] - 2s 2ms/step - loss: 0.4655 - val_loss: 0.5594
# Epoch 98/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4687 - val_loss: 0.5779
# Epoch 99/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4667 - val_loss: 0.5726
# Epoch 100/100
# 915/915 [==============================] - 3s 3ms/step - loss: 0.4657 - val_loss: 0.5640
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:47: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 490/490 [==============================] - 1s 1ms/step
# 풍속 예측이 완료되었습니다. 결과가 submission.csv에 저장되었습니다.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import KFold

# train.csv 파일 불러오기
train_data = pd.read_csv('train.csv')

# 결측치를 평균값으로 대체
train_data = train_data.fillna(train_data.mean())

# '측정 시간대'를 원핫 인코딩하여 숫자 형태로 변환
encoder = OneHotEncoder(sparse=False)
time_encoded = encoder.fit_transform(train_data[['측정 시간대']])
time_encoded_df = pd.DataFrame(time_encoded, columns=encoder.get_feature_names(['측정 시간대']))
train_data = pd.concat([train_data, time_encoded_df], axis=1).drop(['측정 시간대'], axis=1)

# 풍속을 예측할 특성(입력 변수)과 풍속(출력 변수)을 분리합니다.
X = train_data.drop(['ID', '풍속 (m/s)'], axis=1)  # 입력 변수들
y = train_data['풍속 (m/s)']  # 출력 변수 (풍속)

# 신경망 모델 구성
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])

# 모델 컴파일
model.compile(optimizer='adam', loss='mean_squared_error')

# 데이터 정규화 (Normalization)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Cross Validation 수행
kf = KFold(n_splits=5, shuffle=True, random_state=42)
mse_scores = []
for train_index, test_index in kf.split(X_scaled):
    X_train, X_test = X_scaled[train_index], X_scaled[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=0)
    y_pred = model.predict(X_test).flatten()
    mse_scores.append(mean_squared_error(y_test, y_pred))

# 평균 RMSE 출력
print("평균 RMSE:", np.sqrt(np.mean(mse_scores)))
# Out:
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   from ipykernel import kernelapp as app
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 229/229 [==============================] - 0s 1ms/step
# 229/229 [==============================] - 0s 2ms/step
# 229/229 [==============================] - 0s 2ms/step
# 229/229 [==============================] - 0s 2ms/step
# 229/229 [==============================] - 0s 1ms/step
# 평균 RMSE: 0.675133796867023
